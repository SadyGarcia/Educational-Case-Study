# %% [markdown]
# # **Educational System Case Study**

# %% [markdown]
# *By Sady García*

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# The dataset aims to analyze and understand the factors influencing student enrollment, academic performance, and socio-economic background in higher education institutions. \
# The goal is to identify patterns, trends, and potential areas for intervention or improvement in the educational system. \
# Additionally, the dataset can be utilized to develop predictive models to forecast student success rates. This analysis can provide valuable insights for educational policymakers, administrators, and stakeholders to enhance educational access, equity, and quality.

# %% [markdown]
# ## Approach

# %% [markdown]
# *   Understanding the data across relevant columns for the dataset such as 'Curricular units 1st sem (grades)
# *   Searching for missing values to assure te accuracy of the analysis
# * Exploration of the data to gain insights. Using summary statistics to understand the values distributuion
# * Visualization techniques to identify patterns and trends in student enrollment, academic performance and economic indicators.
# * Developing predictive models using Machine Learning Algorithms as Random Forest and Linear Regression to forecast student success rates
# * Evaluating the model performance and identifying significant factors influencing student outcomes
# * Providing recommendation and conclusions

# %% [markdown]
# # Data Outlook

# %% [markdown]
# Starting with the libraries needed for the study, and a brief outlook of the dataset to understand the structure and the content of the data.

# %%
# Supress Warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import axes
import plotly.express as px
import matplotlib.colors as mcolors

# %%
# Read the given CSV file, and view some sample records
data = pd.read_csv("Data.csv")
data.head()
# Out:
#    Marital status  Application mode  Application order  Course  \
# 0               1                 8                  5       2
# 1               1                 6                  1      11
# 2               1                 1                  5       5
# 3               1                 8                  2      15
# 4               2                12                  1       3
#
#    Daytime/evening attendance  Previous qualification  Nacionality  \
# 0                           1                       1            1
# 1                           1                       1            1
# 2                           1                       1            1
# 3                           1                       1            1
# 4                           0                       1            1
#
#    Mother's qualification  Father's qualification  Mother's occupation  ...  \
# 0                      13                      10                    6  ...
# ...

# %% [markdown]
# ## Data Type

# %% [markdown]
# Check the different data types in the DataFrame, some of them are numerical type and some of categorical type.

# %%
# Obtain the shape
data.shape
# Out:
# (4424, 35)

# %%
# Obtain the information of variables to check their data types.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4424 entries, 0 to 4423
# Data columns (total 35 columns):
#  #   Column                                          Non-Null Count  Dtype
# ---  ------                                          --------------  -----
#  0   Marital status                                  4424 non-null   int64
#  1   Application mode                                4424 non-null   int64
#  2   Application order                               4424 non-null   int64
#  3   Course                                          4424 non-null   int64
#  4   Daytime/evening attendance                      4424 non-null   int64
#  5   Previous qualification                          4424 non-null   int64
#  6   Nacionality                                     4424 non-null   int64
#  7   Mother's qualification                          4424 non-null   int64
#  8   Father's qualification                          4424 non-null   int64
# ...

# %%
# Obtain the columns name
data.columns
# Out:
# Index(['Marital status', 'Application mode', 'Application order', 'Course',
#        'Daytime/evening attendance', 'Previous qualification', 'Nacionality',
#        'Mother's qualification', 'Father's qualification',
#        'Mother's occupation', 'Father's occupation', 'Displaced',
#        'Educational special needs', 'Debtor', 'Tuition fees up to date',
#        'Gender', 'Scholarship holder', 'Age at enrollment', 'International',
#        'Curricular units 1st sem (credited)',
#        'Curricular units 1st sem (enrolled)',
#        'Curricular units 1st sem (evaluations)',
#        'Curricular units 1st sem (approved)',
#        'Curricular units 1st sem (grade)',
#        'Curricular units 1st sem (without evaluations)',
#        'Curricular units 2nd sem (credited)',
#        'Curricular units 2nd sem (enrolled)',
#        'Curricular units 2nd sem (evaluations)',
#        'Curricular units 2nd sem (approved)',
#        'Curricular units 2nd sem (grade)',
# ...

# %%
# Obtain a sample
data.sample(5)
# Out:
#       Marital status  Application mode  Application order  Course  \
# 2710               1                 8                  1      11
# 2873               5                13                  1      11
# 3505               1                 8                  3       9
# 3074               2                 2                  1       9
# 390                1                15                  1       6
#
#       Daytime/evening attendance  Previous qualification  Nacionality  \
# 2710                           1                       1            1
# 2873                           1                       2            1
# 3505                           1                       1            1
# 3074                           1                       2            1
# 390                            1                      14            1
#
#       Mother's qualification  Father's qualification  Mother's occupation  \
# ...

# %% [markdown]
# ## Data Verification

# %% [markdown]
# Check missing values in the dataset, or if there are
#
# *   Missing values
# *   Inconsistency in the columns
# * Non useful columns for the study

# %%
# Verify if there are missing values
data.isnull().any()
# Out:
# Marital status                                    False
# Application mode                                  False
# Application order                                 False
# Course                                            False
# Daytime/evening attendance                        False
# Previous qualification                            False
# Nacionality                                       False
# Mother's qualification                            False
# Father's qualification                            False
# Mother's occupation                               False
# Father's occupation                               False
# Displaced                                         False
# Educational special needs                         False
# Debtor                                            False
# Tuition fees up to date                           False
# Gender                                            False
# Scholarship holder                                False
# ...

# %%
# Verify if there are missing values
data.isna().any()
# Out:
# Marital status                                    False
# Application mode                                  False
# Application order                                 False
# Course                                            False
# Daytime/evening attendance                        False
# Previous qualification                            False
# Nacionality                                       False
# Mother's qualification                            False
# Father's qualification                            False
# Mother's occupation                               False
# Father's occupation                               False
# Displaced                                         False
# Educational special needs                         False
# Debtor                                            False
# Tuition fees up to date                           False
# Gender                                            False
# Scholarship holder                                False
# ...

# %% [markdown]
# ## Data Description

# %% [markdown]
# Statistical description of  the numerical data

# %%
#Describe the dataset
data.describe()
# Out:
#        Marital status  Application mode  Application order       Course  \
# count     4424.000000       4424.000000        4424.000000  4424.000000
# mean         1.178571          6.886980           1.727848     9.899186
# std          0.605747          5.298964           1.313793     4.331792
# min          1.000000          1.000000           0.000000     1.000000
# 25%          1.000000          1.000000           1.000000     6.000000
# 50%          1.000000          8.000000           1.000000    10.000000
# 75%          1.000000         12.000000           2.000000    13.000000
# max          6.000000         18.000000           9.000000    17.000000
#
#        Daytime/evening attendance  Previous qualification  Nacionality  \
# count                 4424.000000             4424.000000  4424.000000
# mean                     0.890823                2.531420     1.254521
# std                      0.311897                3.963707     1.748447
# ...

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# Analyze and visualize the different categories across the dataset.
# As well divide the columns in different categories such as:
#
#
# *   Enrollment patterns
# *   Academic performance
# * Economic indicators\
# To make the understanding and the study more clear

# %% [markdown]
# ## Data Categories

# %% [markdown]
# ### Enrollment patterns

# %% [markdown]
# #### Marital Status

# %%
print('\nThere are {} categories in the variable'. format(data['Marital status'].value_counts().count()))
data['Marital status'].value_counts()
# Out:
# There are 6 categories in the variable Marital Status
# Marital status
# 1    3919
# 2     379
# 4      91
# 5      25
# 6       6
# 3       4
# Name: count, dtype: int64

# %% [markdown]
# #### Application mode

# %%
print('\nThere are {} categories in the variable '. format(data['Application mode'].value_counts().count()))
data['Application mode'].value_counts()
# Out:
# There are 18 categories in the variable Application mode
# Application mode
# 1     1708
# 8      872
# 12     785
# 14     312
# 15     213
# 4      139
# 9      124
# 13      77
# 16      59
# 7       38
# 17      35
# 6       30
# 3       16
# 5       10
# 2        3
# 18       1
# 10       1
# 11       1
# Name: count, dtype: int64

# %% [markdown]
# #### Application Order

# %%
print('\nThere are {} categories in the variable'. format(data['Application order'].value_counts().count()))
data['Application order'].value_counts()
# Out:
# There are 8 categories in the variable Application order
# Application order
# 1    3026
# 2     547
# 3     309
# 4     249
# 5     154
# 6     137
# 9       1
# 0       1
# Name: count, dtype: int64

# %% [markdown]
# #### Previous Qualification

# %%
print('\nThere are {} categories in the variable'. format(data['Previous qualification'].value_counts().count()))
data['Previous qualification'].value_counts()
# Out:
# There are 17 categories in the variable
# Previous qualification
# 1     3717
# 14     219
# 12     162
# 3      126
# 9       45
# 15      40
# 16      36
# 2       23
# 6       16
# 7       11
# 4        8
# 13       7
# 17       6
# 8        4
# 11       2
# 5        1
# 10       1
# Name: count, dtype: int64

# %% [markdown]
# #### Nationality

# %%
print('\nThere are {} categories in the variable '. format(data['Nacionality'].value_counts().count()))
data['Nacionality'].value_counts()
# Out:
# There are 21 categories in the variable
# Nacionality
# 1     4314
# 14      38
# 12      14
# 9       13
# 3       13
# 10       5
# 16       3
# 4        3
# 18       3
# 8        2
# 17       2
# 15       2
# 11       2
# 2        2
# 19       2
# 13       1
# 5        1
# 21       1
# 20       1
# 6        1
# 7        1
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['International'].value_counts().count()))
data['International'].value_counts()
# Out:
# There are 2 categories in the variable
# International
# 0    4314
# 1     110
# Name: count, dtype: int64

# %% [markdown]
# #### Sociological Background

# %%
print('\nThere are {} categories in the variable '. format(data["Mother's qualification"].value_counts().count()))
data["Mother's qualification"].value_counts()
# Out:
# There are 29 categories in the variable
# Mother's qualification
# 1     1069
# 22    1009
# 13     953
# 23     562
# 3      438
# 19     130
# 2       83
# 4       49
# 10      42
# 5       21
# 25       9
# 7        8
# 24       8
# 26       6
# 6        4
# 27       4
# 28       4
# 17       3
# 8        3
# 9        3
# 21       3
# 20       3
# 18       3
# 11       2
# 12       1
# 14       1
# 16       1
# 15       1
# 29       1
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data["Father's qualification"].value_counts().count()))
data["Father's qualification"].value_counts()
# Out:
# There are 34 categories in the variable
# Father's qualification
# 27    1209
# 14     968
# 1      904
# 28     702
# 3      282
# 24     112
# 2       68
# 4       39
# 10      38
# 29      20
# 5       18
# 9       10
# 26       8
# 7        5
# 30       5
# 16       4
# 21       4
# 12       4
# 20       3
# 25       2
# 31       2
# 33       2
# 8        2
# 6        2
# 18       2
# 17       1
# 19       1
# 23       1
# 34       1
# 15       1
# 32       1
# 13       1
# 11       1
# 22       1
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data["Mother's occupation"].value_counts().count()))
data["Mother's occupation"].value_counts()
# Out:
# There are 32 categories in the variable
# Mother's occupation
# 10    1577
# 5      817
# 6      530
# 4      351
# 3      318
# 8      272
# 1      144
# 2      102
# 7       91
# 12      70
# 9       36
# 29      26
# 13      17
# 32      11
# 20       8
# 15       7
# 22       6
# 28       5
# 30       5
# 31       4
# 19       4
# 11       4
# 21       3
# 23       3
# 18       3
# 24       2
# 14       2
# 25       2
# 27       1
# 16       1
# 17       1
# 26       1
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data["Father's occupation"].value_counts().count()))
data["Father's occupation"].value_counts()
# Out:
# There are 46 categories in the variable
# Father's occupation
# 10    1010
# 8      666
# 6      516
# 5      386
# 4      384
# 9      318
# 11     266
# 7      242
# 3      197
# 2      134
# 1      128
# 12      65
# 13      19
# 44      15
# 29       8
# 36       8
# 43       6
# 35       5
# 16       4
# 39       4
# 26       3
# 42       3
# 31       3
# 21       3
# 40       3
# 45       2
# 41       2
# 17       2
# 30       2
# 37       2
# 20       2
# 15       2
# 32       1
# 14       1
# 18       1
# 38       1
# 27       1
# 24       1
# 25       1
# 28       1
# 23       1
# 34       1
# 46       1
# 19       1
# 22       1
# 33       1
# Name: count, dtype: int64

# %% [markdown]
# #### Displaced

# %%
print('\nThere are {} categories in the variable '. format(data['Displaced'].value_counts().count()))
data['Displaced'].value_counts()
# Out:
# There are 2 categories in the variable
# Displaced
# 1    2426
# 0    1998
# Name: count, dtype: int64

# %% [markdown]
# #### Special Needs

# %%
print('\nThere are {} categories in the variable '. format(data['Educational special needs'].value_counts().count()))
data['Educational special needs'].value_counts()
# Out:
# There are 2 categories in the variable
# Educational special needs
# 0    4373
# 1      51
# Name: count, dtype: int64

# %% [markdown]
# #### Economic Background

# %%
print('\nThere are {} categories in the variable '. format(data['Debtor'].value_counts().count()))
data['Debtor'].value_counts()
# Out:
# There are 2 categories in the variable
# Debtor
# 0    3921
# 1     503
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['Tuition fees up to date'].value_counts().count()))
data['Tuition fees up to date'].value_counts()
# Out:
# There are 2 categories in the variable
# Tuition fees up to date
# 1    3896
# 0     528
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['Scholarship holder'].value_counts().count()))
data['Scholarship holder'].value_counts()
# Out:
# There are 2 categories in the variable
# Scholarship holder
# 0    3325
# 1    1099
# Name: count, dtype: int64

# %% [markdown]
# #### Gender

# %%
print('\nThere are {} categories in the variable '. format(data['Gender'].value_counts().count()))
data['Gender'].value_counts()
# Out:
# There are 2 categories in the variable
# Gender
# 0    2868
# 1    1556
# Name: count, dtype: int64

# %% [markdown]
# #### Age

# %%
print('\nThere are {} categories in the variable '. format(data['Age at enrollment'].value_counts().count()))
data['Age at enrollment'].value_counts()
# Out:
# There are 46 categories in the variable
# Age at enrollment
# 18    1036
# 19     911
# 20     599
# 21     322
# 22     174
# 24     131
# 23     108
# 26      94
# 25      93
# 27      91
# 28      83
# 29      66
# 32      61
# 34      60
# 31      55
# 35      49
# 30      49
# 33      45
# 37      42
# 39      38
# 36      35
# 41      31
# 38      29
# 43      25
# 40      23
# 45      22
# 44      21
# 47      18
# 50      16
# 42      13
# 49      13
# 46      12
# 48      11
# 51       7
# 54       7
# 53       7
# 17       5
# 55       5
# 52       4
# 59       3
# 58       3
# 57       2
# 60       2
# 61       1
# 70       1
# 62       1
# Name: count, dtype: int64

# %% [markdown]
# ### Economic Indicators

# %% [markdown]
# #### Unemployment Rate

# %%
print('\nThere are {} categories in the variable '. format(data['Unemployment rate'].value_counts().count()))
data['Unemployment rate'].value_counts()
# Out:
# There are 10 categories in the variable
# Unemployment rate
# 7.6     571
# 9.4     533
# 10.8    525
# 12.4    445
# 12.7    419
# 11.1    414
# 15.5    397
# 13.9    390
# 8.9     368
# 16.2    362
# Name: count, dtype: int64

# %% [markdown]
# #### Inflation Rate

# %%
print('\nThere are {} categories in the variable '. format(data['Inflation rate'].value_counts().count()))
data['Inflation rate'].value_counts()
# Out:
# There are 9 categories in the variable
# Inflation rate
#  1.4    893
#  2.6    571
# -0.8    533
#  0.5    445
#  3.7    419
#  0.6    414
#  2.8    397
# -0.3    390
#  0.3    362
# Name: count, dtype: int64

# %% [markdown]
# #### GDP

# %%
print('\nThere are {} categories in the variable '. format(data['GDP'].value_counts().count()))
data['GDP'].value_counts()
# Out:
# There are 10 categories in the variable
# GDP
#  0.32    571
# -3.12    533
#  1.74    525
#  1.79    445
# -1.70    419
#  2.02    414
# -4.06    397
#  0.79    390
#  3.51    368
# -0.92    362
# Name: count, dtype: int64

# %% [markdown]
# ### Target

# %%
print('\nThere are {} categories in the variable '. format(data['Target'].value_counts().count()))
data['Target'].value_counts()
# Out:
# There are 3 categories in the variable
# Target
# Graduate    2209
# Dropout     1421
# Enrolled     794
# Name: count, dtype: int64

# %% [markdown]
# ### Academic Performance

# %% [markdown]
# #### Attendance

# %%
print('\nThere are {} categories in the variable '. format(data['Daytime/evening attendance'].value_counts().count()))
data['Daytime/evening attendance'].value_counts()
# Out:
# There are 2 categories in the variable
# Daytime/evening attendance
# 1    3941
# 0     483
# Name: count, dtype: int64

# %% [markdown]
# #### 1st semester

# %%
print('\nThere are {} categories in the variable '. format(data['Curricular units 1st sem (approved)'].value_counts().count()))
data['Curricular units 1st sem (approved)'].value_counts()
# Out:
# There are 23 categories in the variable
# Curricular units 1st sem (approved)
# 6     1171
# 5      723
# 0      718
# 7      471
# 4      433
# 3      269
# 2      160
# 1      127
# 8      108
# 11      49
# 12      44
# 9       40
# 13      26
# 10      24
# 18      15
# 14      14
# 17      10
# 15       7
# 16       5
# 21       4
# 20       3
# 19       2
# 26       1
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['Curricular units 1st sem (credited)'].value_counts().count()))
data['Curricular units 1st sem (credited)'].value_counts()
# Out:
# There are 21 categories in the variable
# Curricular units 1st sem (credited)
# 0     3847
# 2       94
# 1       85
# 3       69
# 6       51
# 4       47
# 7       41
# 5       41
# 8       31
# 9       27
# 11      17
# 10      15
# 14      15
# 13      13
# 12      12
# 15       5
# 18       4
# 17       3
# 16       3
# 19       2
# 20       2
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['Curricular units 1st sem (approved)'].value_counts().count()))
data['Curricular units 1st sem (evaluations)'].value_counts()
# Out:
# There are 23 categories in the variable
# Curricular units 1st sem (evaluations)
# 8     791
# 7     703
# 6     598
# 9     402
# 0     349
# 10    340
# 11    239
# 12    223
# 5     220
# 13    140
# 14    105
# 15     70
# 16     47
# 17     33
# 18     30
# 19     23
# 4      19
# 21     17
# 20     12
# 22     10
# 23      9
# 2       8
# 3       6
# 24      6
# 1       6
# 26      4
# 25      3
# 27      2
# 29      2
# 45      2
# 32      1
# 36      1
# 31      1
# 28      1
# 33      1
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['Curricular units 1st sem (enrolled)'].value_counts().count()))
data['Curricular units 1st sem (enrolled)'].value_counts()
# Out:
# There are 23 categories in the variable
# Curricular units 1st sem (enrolled)
# 6     1910
# 5     1010
# 7      656
# 8      296
# 0      180
# 12      66
# 10      52
# 11      45
# 9       36
# 15      25
# 14      22
# 4       21
# 13      20
# 18      19
# 17      16
# 16      13
# 3       10
# 2        9
# 1        7
# 21       6
# 19       2
# 23       2
# 26       1
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['Curricular units 1st sem (grade)'].value_counts().count()))
data['Curricular units 1st sem (grade)'].value_counts()
# Out:
# There are 797 categories in the variable
# Curricular units 1st sem (grade)
# 0.000000     718
# 12.000000    205
# 13.000000    147
# 11.000000    138
# 11.500000     89
#             ...
# 13.040000      1
# 15.657143      1
# 13.331429      1
# 15.028571      1
# 14.912500      1
# Name: count, Length: 797, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['Curricular units 1st sem (without evaluations)'].value_counts().count()))
data['Curricular units 1st sem (without evaluations)'].value_counts()
# Out:
# There are 11 categories in the variable
# Curricular units 1st sem (without evaluations)
# 0     4130
# 1      153
# 2       79
# 3       23
# 4       15
# 6        6
# 7        6
# 5        5
# 8        4
# 12       2
# 10       1
# Name: count, dtype: int64

# %% [markdown]
# #### 2nd semester

# %%
print('\nThere are {} categories in the variable '. format(data['Curricular units 2nd sem (approved)'].value_counts().count()))
data['Curricular units 2nd sem (approved)'].value_counts()
# Out:
# There are 20 categories in the variable
# Curricular units 2nd sem (approved)
# 6     965
# 0     870
# 5     726
# 4     414
# 7     331
# 8     321
# 3     285
# 2     198
# 1     114
# 11     48
# 10     38
# 9      36
# 12     34
# 13     21
# 17      8
# 14      6
# 19      3
# 20      2
# 16      2
# 18      2
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['Curricular units 2nd sem (credited)'].value_counts().count()))
data['Curricular units 2nd sem (credited)'].value_counts()
# Out:
# There are 19 categories in the variable
# Curricular units 2nd sem (credited)
# 0     3894
# 1      107
# 2       92
# 4       78
# 5       68
# 3       49
# 6       26
# 11      20
# 7       16
# 9       15
# 12      14
# 10      13
# 8       12
# 13       9
# 14       4
# 15       2
# 16       2
# 18       2
# 19       1
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['Curricular units 2nd sem (enrolled)'].value_counts().count()))
data['Curricular units 2nd sem (enrolled)'].value_counts()
# Out:
# There are 22 categories in the variable
# Curricular units 2nd sem (enrolled)
# 6     1913
# 5     1054
# 8      661
# 7      304
# 0      180
# 11      60
# 9       50
# 10      48
# 12      44
# 13      37
# 14      22
# 4       17
# 17      12
# 2        5
# 19       3
# 3        3
# 1        3
# 15       2
# 23       2
# 18       2
# 16       1
# 21       1
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['Curricular units 2nd sem (approved)'].value_counts().count()))
data['Curricular units 2nd sem (evaluations)'].value_counts()
# Out:
# There are 20 categories in the variable
# Curricular units 2nd sem (evaluations)
# 8     792
# 6     614
# 7     563
# 9     456
# 0     401
# 10    355
# 5     288
# 11    255
# 12    226
# 13    126
# 14     98
# 15     73
# 16     49
# 17     25
# 18     22
# 19     19
# 4      10
# 21     10
# 22     10
# 20      8
# 2       4
# 23      4
# 26      3
# 24      3
# 1       3
# 3       2
# 27      2
# 28      1
# 25      1
# 33      1
# Name: count, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['Curricular units 2nd sem (grade)'].value_counts().count()))
data['Curricular units 2nd sem (grade)'].value_counts()
# Out:
# There are 782 categories in the variable
# Curricular units 2nd sem (grade)
# 0.000000     870
# 12.000000    170
# 11.000000    165
# 13.000000    150
# 11.500000     86
#             ...
# 13.994444      1
# 11.685714      1
# 15.657143      1
# 13.331429      1
# 11.083333      1
# Name: count, Length: 782, dtype: int64

# %%
print('\nThere are {} categories in the variable '. format(data['Curricular units 2nd sem (without evaluations)'].value_counts().count()))
data['Curricular units 2nd sem (without evaluations)'].value_counts()
# Out:
# There are 10 categories in the variable
# Curricular units 2nd sem (without evaluations)
# 0     4142
# 1      140
# 2       48
# 3       35
# 4       21
# 5       17
# 6        8
# 8        6
# 7        5
# 12       2
# Name: count, dtype: int64

# %% [markdown]
# #### Course

# %%
print('\nThere are {} categories in the variable'. format(data['Course'].value_counts().count()))
data['Course'].value_counts()
# Out:
# There are 17 categories in the variable Course
# Course
# 12    766
# 9     380
# 10    355
# 6     337
# 15    331
# 14    268
# 17    268
# 11    252
# 5     226
# 2     215
# 3     215
# 4     210
# 16    192
# 7     170
# 8     141
# 13     86
# 1      12
# Name: count, dtype: int64

# %% [markdown]
# ## Univariate Visualization

# %% [markdown]
# ### Academic Performance

# %% [markdown]
# #### Grades

# %%
#Median and Mean 1st sem
print('Median Grade 1st sem', data['Curricular units 1st sem (grade)'].median())
print('Mean Grade 1st sem', data['Curricular units 1st sem (grade)'].mean())
#Median and Mean 2nd sem
print('Median Grade 2nd sem', data['Curricular units 2nd sem (grade)'].median())
print('Mean Grade 2nd sem', data['Curricular units 2nd sem (grade)'].mean())
# Out:
# Median Grade 1st sem 12.28571429
# Mean Grade 1st sem 10.640821575178572
# Median Grade 2nd sem 12.2
# Mean Grade 2nd sem 10.230205722719258

# %%
# Plot the graph of Grades
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.histplot( data['Curricular units 1st sem (grade)'],
             color = 'coral',
              kde = True)
plt.xlabel('Grade')
plt.ylabel('Frequency')
plt.title('Curricular Units 1st sem Grades Histogram')
plt.subplot(2,2,2)
sns.boxplot( data['Curricular units 1st sem (grade)'],
            color = 'coral',
             showmeans = True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'black',
                       'markersize':'5'})
plt.ylabel('Grades')
plt.title('Curricular Units 1st sem Grades Distribution')
plt.subplot(2,2,3)
sns.histplot( data['Curricular units 2nd sem (grade)'],
             color = 'plum',
              kde = True)
plt.xlabel('Grades')
plt.ylabel('Frequency')
plt.title('Curricular Units 2nd sem Grades Histogram')
plt.subplot(2,2,4)
sns.boxplot( data['Curricular units 2nd sem (grade)'],
            color = 'plum',
             showmeans = True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'black',
                       'markersize':'5'})
plt.ylabel('Grades')
plt.title('Curricular Units 2nd sem Grades Distribution')
plt.tight_layout()
plt.savefig('Grades.jpg', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Evaluations

# %%
#Median and Mean
print('Median Evaluation 1st sem', data['Curricular units 1st sem (evaluations)'].median())
print('Mean Evaluation 1st sem', data['Curricular units 1st sem (evaluations)'].mean())
#Median and Mean 2nd sem
print('Median Evaluation 2nd sem', data['Curricular units 2nd sem (evaluations)'].median())
print('Mean Evaluation 2nd sem', data['Curricular units 2nd sem (evaluations)'].mean())
# Out:
# Median Evaluation 1st sem 8.0
# Mean Evaluation 1st sem 8.299050632911392
# Median Evaluation 2nd sem 8.0
# Mean Evaluation 2nd sem 8.063291139240507

# %%
# Plot the graph of Evaluations
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.histplot( data['Curricular units 1st sem (evaluations)'],
             color = 'coral',
              kde = True)
plt.xlabel('Evaluation')
plt.ylabel('Frequency')
plt.title('Curricular Units 1st sem Evaluations Histogram')
plt.subplot(2,2,2)
sns.boxplot( data['Curricular units 1st sem (evaluations)'],
            color = 'coral',
             showmeans = True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'white',
                       'markersize':'5'})
plt.ylabel('Evaluation')
plt.title('Curricular Units 1st sem Evaluations Distribution')
plt.subplot(2,2,3)
sns.histplot( data['Curricular units 2nd sem (evaluations)'],
             color = 'plum',
              kde = True)
plt.xlabel('Evaluation')
plt.ylabel('Frequency')
plt.title('Curricular Units 2nd sem Evaluations Histogram')
plt.subplot(2,2,4)
sns.boxplot( data['Curricular units 2nd sem (evaluations)'],
            color = 'plum',
             showmeans = True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'white',
                       'markersize':'5'})
plt.ylabel('Evaluation')
plt.title('Curricular Units 2nd sem Evaluations Distribution')
plt.show()

# %% [markdown]
# #### Approved

# %%
# Plot the graph of Approved
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot( data['Curricular units 1st sem (approved)'],
             color = 'coral',
              kde = True)
plt.xlabel('Approved')
plt.ylabel('Frequency')
plt.title('Curricular Units 1st sem Approved Histogram')
plt.subplot(2,2,2)
sns.boxplot( data['Curricular units 1st sem (approved)'],
            color = 'coral',
             showmeans = True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'black',
                       'markersize':'5'})
plt.ylabel('Approved')
plt.title('Curricular Units 1st sem Approved Distribution')
plt.subplot(2,2,3)
sns.distplot( data['Curricular units 2nd sem (approved)'],
             color = 'plum',
              kde = True)
plt.xlabel('Approved')
plt.ylabel('Frequency')
plt.title('Curricular Units 2nd sem Approved Histogram')
plt.subplot(2,2,4)
sns.boxplot( data['Curricular units 2nd sem (approved)'],
            color = 'plum',
             showmeans = True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'black',
                       'markersize':'5'})
plt.ylabel('Approved')
plt.title('Curricular Units 2nd sem Approved Distribution')
plt.show()

# %% [markdown]
# #### Enrolled

# %%
# Plot the graph
plt.figure(figsize=(10,10))
plt.subplot(2,2,1)
sns.distplot( data['Curricular units 1st sem (enrolled)'],
             color = 'coral',
              kde = True)

plt.ylabel('Frequency')
plt.title('Curricular Units 1st sem Enrolled Histogram')
plt.subplot(2,2,2)
sns.boxplot( data['Curricular units 1st sem (enrolled)'],
            color = 'coral',
             showmeans = True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'black',
                       'markersize':'5'})

plt.title('Curricular Units 1st sem Enrolled Distribution')
plt.subplot(2,2,3)
sns.distplot( data['Curricular units 2nd sem (enrolled)'],
             color = 'plum',
              kde = True)

plt.ylabel('Frequency')
plt.title('Curricular Units 2nd sem Enrolled Histogram')
plt.subplot(2,2,4)
sns.boxplot( data['Curricular units 2nd sem (enrolled)'],
            color = 'plum',
             showmeans = True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'black',
                       'markersize':'5'})

plt.title('Curricular Units 2nd sem Enrolled Distribution')
plt.show()

# %% [markdown]
# #### Attendance

# %%
#Median and Mean
print('Median Attendance', data['Daytime/evening attendance'].median())
print('Mean Attendance', data['Daytime/evening attendance'].mean())
# Out:
# Median Attendance 1.0
# Mean Attendance 0.8908227848101266

# %%
per_attendance = (data['Daytime/evening attendance'].value_counts()/len(data))*100

fig = px.pie(
    values = per_attendance.values,
    names = per_attendance.index,
    title = 'Attendance Percentage',
   color_discrete_sequence=['lightseagreen', 'tomato'],
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Course

# %%
# Plot the  bar graph of Course
per_course = (data['Course'].value_counts()/len(data))*100
plt.figurefigsize=(4,4)
sns.barplot(x = per_course.index,
            y = per_course.values,
             palette='dark')
plt.xlabel('Course')
plt.ylabel('Percentage')
plt.title('Percentage for Each Course')
plt.show()

# %% [markdown]
# ### Enrollment Patterns

# %% [markdown]
# #### Age

# %%
#Median and Mean
print('Median Age at Enrollment', data['Age at enrollment'].median())
print('Mean Age at Enrollment', data['Age at enrollment'].mean())
# Out:
# Median Age at Enrollment 20.0
# Mean Age at Enrollment 23.265144665461122

# %%
# Plot the graph of Age at enrollment
plt.figure(figsize=(8,4))
plt.subplot(1,2,1)
sns.histplot( data['Age at enrollment'],
             color = 'palegreen',
              kde = True)
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age at Enrollment Histogram')
plt.subplot(1,2,2)
sns.boxplot( data['Age at enrollment'],
            color = 'palegreen',
             showmeans = True)
plt.ylabel('Age')
plt.title('Age Mean Distribution')
plt.tight_layout()
plt.savefig('Age.jpg', bbox_inches='tight')
plt.show()

# %%
#create the buckets from age column
bucket = [0, 21, 30, 40, 50, float('inf')]
labels = ['<21', '21-30', '30-40', '40-50', '50+']
data['age_bucket'] = pd.cut(data['Age at enrollment'], bins=bucket, labels=labels, right=False)

print(data['age_bucket'].sample(5))
# Out:
# 2294    21-30
# 3245    21-30
# 2204      <21
# 804       <21
# 255     30-40
# Name: age_bucket, dtype: category
# Categories (5, object): ['<21' < '21-30' < '30-40' < '40-50' < '50+']

# %%
 #Visualize the distribution of the age at enrolment
 plt.figure(figsize=(4,4))
 sns.countplot(data['age_bucket'],
               palette = 'pastel' )
 plt.ylabel('Age Bucket')
 plt.xlabel( 'Frequence')
 plt.title('Age Bucket Distribution')
 plt.tight_layout()
plt.savefig('Age-bucket.jpg', bbox_inches='tight')
 plt.show()

# %% [markdown]
# #### Displaced

# %%
per_displaced = (data['Displaced'].value_counts()/len(data))*100

fig = px.pie(
    values = per_displaced.values,
    names = per_displaced.index,
    title = 'Displaced Percentage',
   color_discrete_sequence=['lightseagreen', 'tomato'],
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Debtor

# %%
per_debtor = (data['Debtor'].value_counts()/len(data))*100

fig = px.pie(
    values = per_debtor.values,
    names = per_debtor.index,
    title = 'Debtor Percentage',
   color_discrete_sequence=['tomato','lightseagreen']
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Special Needs

# %%
per_special = (data['Educational special needs'].value_counts()/len(data))*100

fig = px.pie(
    values = per_special.values,
    names = per_special.index,
    title = 'Educational Special Needs Percentage',
   color_discrete_sequence=['tomato','lightseagreen']
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Tuition

# %%
per_tuition = (data['Tuition fees up to date'].value_counts()/len(data))*100

fig = px.pie(
    values = per_tuition.values,
    names = per_tuition.index,
    title = 'Tuition fees Up to Date Percentage',
   color_discrete_sequence=['lightseagreen', 'tomato']
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Gender

# %%
per_gender = (data['Gender'].value_counts()/len(data))*100

fig = px.pie(
    values = per_gender.values,
    names = per_gender.index,
    title = 'Gender',
   color_discrete_sequence=['lightpink','skyblue']
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Scholarship

# %%
per_scholarship = (data['Scholarship holder'].value_counts()/len(data))*100

fig = px.pie(
    values = per_scholarship.values,
    names = per_scholarship.index,
    title = 'Scholarship Holder Percentage',
   color_discrete_sequence=['tomato','lightseagreen']
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### International Students

# %%
per_international = (data['International'].value_counts()/len(data))*100

fig = px.pie(
    values = per_international.values,
    names = per_international.index,
    title = 'International Students Percentage',
   color_discrete_sequence=['tomato','lightseagreen']
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #### Marital status

# %%
# Plot the  bar graph of marital status
per_marital = (data['Marital status'].value_counts()/len(data))*100
plt.figurefigsize=(4,4)
sns.barplot(x = per_marital.index,
            y = per_marital.values,
             palette='dark')
plt.xlabel('Marital Status')
plt.ylabel('Percentage')
plt.title('Percentage of Marital Status')
plt.show()

# %% [markdown]
# #### Previous Qualification

# %%
#Visualize the distribution or Previous Qualification
per_preq = (data['Previous qualification'].value_counts()/len(data))*100
plt.figurefigsize=(4,4)
sns.barplot(x = per_preq.index,
            y = per_preq.values,
             palette= 'pastel')
plt.xlabel('Previous Qualification')
plt.ylabel('Percentage')
plt.title('Previous Qualification Distribution')
plt.show()

# %% [markdown]
# ### Target

# %%
# Plot the graph of Target
per_target = (data['Target'].value_counts()/len(data))*100
plt.figure(figsize=(4,4))
sns.barplot(x = per_target.index,
            y = per_target.values,
            palette = 'colorblind')
plt.xlabel('Target')
plt.ylabel('Percentage')
plt.title('Percentage of Target')
plt.tight_layout()
plt.savefig('Target.jpg', bbox_inches='tight')
plt.show()

# %% [markdown]
# ### Economic Indicators

# %% [markdown]
# #### Inflation Rate

# %%
#Plot the grap of Inflation Rate
plt.figure(figsize=(5,5))
sns.countplot(x = 'Inflation rate',
            data = data,
            palette = 'deep')
plt.xlabel('Inflation Rate')
plt.ylabel('Frequence')
plt.title('Frequence of Inflation Rate')
plt.tight_layout()
plt.savefig('IR.jpg', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### GDP

# %%
#Plot the graph of GDP
plt.figure(figsize=(6,4))
sns.countplot(x = 'GDP',
            data = data,
            palette = 'dark')
plt.xlabel('GDP')
plt.ylabel('Frequence')
plt.title('Frequence of GDP')
plt.tight_layout()
plt.savefig('gdp.jpg', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Unemployment Rate

# %%
#Plot the graph of Unemployment rate
plt.figure(figsize=(6,4))
sns.countplot(x = 'Unemployment rate',
            data = data,
            palette = 'dark')
plt.xlabel('Unemployment rate')
plt.ylabel('Frequence')
plt.title('Frequence of Unemployment Rate')
plt.tight_layout()
plt.savefig('unemploy.jpg', bbox_inches='tight')
plt.show()

# %% [markdown]
# # Bivariate and Multivariate Analysis

# %% [markdown]
# Analyze and visualize the relation between different categories across the dataset.

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Enrollment patterns

# %% [markdown]
# #### Correlation matrix

# %% [markdown]
# Verify the relation between categories to understand if Linear Regression Algorithms could be applied to the dataset.

# %%
#plot the pair plot
columnas = ['Age at enrollment', 'Gender', 'Course','Scholarship holder', 'Previous qualification']
sns.pairplot(data[columnas], height=2.5)
plt.tight_layout()
plt.show()

# %%
#plot the correlation matrix
columns_heatmap = ['Age at enrollment', 'Gender', 'Course','Scholarship holder',
                   'Previous qualification', 'Marital status']
corr_matrix = data[columns_heatmap].corr()
plt.figure(figsize=(6, 6))
sns.heatmap(corr_matrix, cmap='coolwarm', annot= True)
plt.title('Correlation Matrix ')
plt.tight_layout()
plt.savefig('Fig1.jpg', bbox_inches='tight')
plt.show()

# %%
columns_heatmap_bg = ['Course',"Mother's qualification", "Father's qualification",
       "Mother's occupation", "Father's occupation"]
corr_matrix_bg = data[columns_heatmap_bg].corr()
plt.figure(figsize=(5, 5))
sns.heatmap(corr_matrix_bg, cmap='Purples', annot= True)
plt.title(' Background Correlation Matrix ')
plt.show()

# %% [markdown]
# As the correlation matrix show, there are not a strong correlation between socio-economic background and student performance

# %% [markdown]
# #### Age at Enrollment and Gender

# %%
print('Mean Age per Gender', data.groupby('Gender')['Age at enrollment'].mean())
print('Median Age per Gender', data.groupby('Gender')['Age at enrollment'].median())
# Out:
# Mean Age per Gender Gender
# 0    22.433403
# 1    24.798201
# Name: Age at enrollment, dtype: float64
# Median Age per Gender Gender
# 0    19.0
# 1    21.0
# Name: Age at enrollment, dtype: float64

# %%
print('Max Age per Gender', data.groupby('Gender')['Age at enrollment'].max())
# Out:
# Max Age per Gender Gender
# 0    62
# 1    70
# Name: Age at enrollment, dtype: int64

# %%
gen = {'0': 'lightpink', '1': 'skyblue'}
plt.figure(figsize=(4,4))
sns.boxplot(x='Gender',
            y ='Age at enrollment',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = gen
            )
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Average Age at Enrollment per Gender')
plt.tight_layout()
plt.savefig('age-gender.jpg', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Age vs Course

# %%
# Visualize the distribution per age across Course
plt.figure(figsize=(5,5))
sns.scatterplot(x='age_bucket',
            y ='Course',
            data= data,
            palette = 'deep'
            )
plt.xlabel('Age Bucket')
plt.ylabel('Course')
plt.title('Age at Enrollment per Course')
plt.show()

# %% [markdown]
# #### Age at Enrollment vs Previous Qualification

# %%
plt.figure(figsize=(4,4))
sns.barplot(x='age_bucket',
                y='Previous qualification',
                data=data,
            palette = 'dark')
plt.xlabel('Age at Enrollment')
plt.ylabel('Previous Qualification')
plt.title('Age at Enrollment vs. Previous Qualification')
plt.tight_layout()
plt.savefig('age-pre.jpg', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Gender vs Scholarship holder

# %%
print('Mean Scholarship holder per Gender', data.groupby('Gender')['Scholarship holder'].mean())
print('Median Scholarship Holder per Gender', data.groupby('Gender')['Scholarship holder'].median())
# Out:
# Mean Scholarship holder per Gender Gender
# 0    0.302301
# 1    0.149100
# Name: Scholarship holder, dtype: float64
# Median Scholarship Holder per Gender Gender
# 0    0.0
# 1    0.0
# Name: Scholarship holder, dtype: float64

# %%
gen = {'0': 'lightpink', '1': 'skyblue'}
plt.figure(figsize=(4,4))
sns.barplot(x='Gender',
            y ='Scholarship holder',
            data= data,
            palette = gen
            )
plt.xlabel('Gender')
plt.ylabel('Scholarship Holder')
plt.title('Average Scholarship holder per Gender')
plt.tight_layout()
plt.savefig('gen-scho.jpg', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Gender and Course

# %%
gen = {0: 'lightpink', 1: 'skyblue'}
plt.figure(figsize=(5, 5))
sns.countplot(x='Course',
              hue='Gender',
              data=data,
              palette = gen)

plt.xlabel('Course')
plt.ylabel('Count')
plt.title('Count of Course by Gender')
plt.tight_layout()
plt.savefig('gen-course.jpg', bbox_inches='tight')
plt.show()

# %% [markdown]
# #### Application Mode by Gender

# %%
#Visualize the pattern
gen = {0: 'lightpink', 1: 'skyblue'}
plt.figure(figsize=(5,4))
sns.countplot(x='Application mode',
              hue='Gender',
              data=data,
              palette = gen)
plt.xlabel('Application Mode')
plt.ylabel('Count')
plt.title('Count of Application Mode by Gender')
plt.show()

# %% [markdown]
# #### Marital Status by Gender

# %%
plt.figure(figsize=(5, 5))
sns.countplot(x='Marital status',
              hue='Gender',
              data=data,
              palette = gen)
plt.xlabel('Marital Status')
plt.ylabel('Count')
plt.title('Count of Marital Status by Gender')
plt.show()

# %% [markdown]
# ### Academic Performance

# %% [markdown]
# #### Correlation Matrix

# %%
#plot the correlation matrix in the 1st sem
columns_heatmap_1st = ['Curricular units 1st sem (grade)','Curricular units 1st sem (evaluations)',
                   'Curricular units 1st sem (enrolled)','Curricular units 1st sem (credited)',
                   'Curricular units 1st sem (approved)','Gender',
                       'Age at enrollment','Marital status']
corr_matrix_1st = data[columns_heatmap_1st].corr()
plt.figure(figsize=(7, 7))
sns.heatmap(corr_matrix_1st, cmap='coolwarm', annot= True)
plt.title('Correlation Matrix ')
plt.show()

# %%
#plot the correlation matrix in the 2nd sem
columns_heatmap_2nd = ['Curricular units 2nd sem (grade)','Curricular units 2nd sem (evaluations)',
                   'Curricular units 2nd sem (enrolled)','Curricular units 2nd sem (credited)',
                   'Curricular units 2nd sem (approved)','Gender',
                       'Age at enrollment','Marital status']
corr_matrix_2nd = data[columns_heatmap_2nd].corr()
plt.figure(figsize=(7, 7))
sns.heatmap(corr_matrix_2nd, cmap='coolwarm', annot= True)
plt.title('Correlation Matrix Sociological Indicators')
plt.show()

# %% [markdown]
# #### Course vs Previous Qualification

# %%
# Plot course vs previous qualification
plt.figure (figsize=(6,4))
sns.boxplot(x= 'Previous qualification',
            y = 'Course',
            palette = 'pastel',
            data = data)
plt.xlabel('Previous Qualification')
plt.ylabel('Course')
plt.title('Previos qualification in Each Course')
plt.show()

# %% [markdown]
# #### Grade per Gender

# %%
print('Mean Grade per Gender', data.groupby('Gender')['Curricular units 1st sem (grade)'].mean())
print('Mean Grade per Gender', data.groupby('Gender')['Curricular units 2nd sem (grade)'].mean())
print('Median Grade per Gender', data.groupby('Gender')['Curricular units 1st sem (grade)'].median())
print('Median Grade per Gender', data.groupby('Gender')['Curricular units 2nd sem (grade)'].median())
# Out:
# Mean Grade per Gender Gender
# 0    11.316641
# 1     9.395159
# Name: Curricular units 1st sem (grade), dtype: float64
# Mean Grade per Gender Gender
# 0    10.994420
# 1     8.821615
# Name: Curricular units 2nd sem (grade), dtype: float64
# Median Grade per Gender Gender
# 0    12.500000
# 1    11.833333
# Name: Curricular units 1st sem (grade), dtype: float64
# Median Grade per Gender Gender
# 0    12.500000
# 1    11.636039
# Name: Curricular units 2nd sem (grade), dtype: float64

# %%
gen = {'0': 'lightpink', '1': 'skyblue'}
plt.figure(figsize=(4,4))
sns.boxplot(x='Gender',
            y ='Curricular units 1st sem (grade)',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = gen
            )
plt.xlabel('Gender')
plt.ylabel('Grade')
plt.title('Average Grade per Gender (1st sem)')
plt.show()

# %%
gen = {'0': 'lightpink', '1': 'skyblue'}
plt.figure(figsize=(4,4))
sns.boxplot(x='Gender',
            y ='Curricular units 2nd sem (grade)',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = gen
            )
plt.xlabel('Gender')
plt.ylabel('Grade')
plt.title('Average Grade per Gender (2nd sem)')
plt.show()

# %% [markdown]
# #### Per Marital Status

# %%
print('Mean Grade per marital status', data.groupby('Marital status')['Curricular units 1st sem (grade)'].mean())
print('Median Grade per Marital status', data.groupby('Marital status')['Curricular units 1st sem (grade)'].median())
print('Mean Grade per marital status', data.groupby('Marital status')['Curricular units 2nd sem (grade)'].mean())
print('Median Grade per Marital status', data.groupby('Marital status')['Curricular units 2nd sem (grade)'].median())
# Out:
# Mean Grade per marital status Marital status
# 1    10.755990
# 2     9.837538
# 3     5.500000
# 4     9.502478
# 5    10.884689
# 6     5.833333
# Name: Curricular units 1st sem (grade), dtype: float64
# Median Grade per Marital status Marital status
# 1    12.333333
# 2    11.833333
# 3     5.100000
# 4    11.625000
# 5    12.375000
# 6     5.333333
# Name: Curricular units 1st sem (grade), dtype: float64
# Mean Grade per marital status Marital status
# 1    10.365832
# 2     9.365956
# 3     6.562500
# 4     8.683925
# 5     9.283385
# 6     6.077778
# Name: Curricular units 2nd sem (grade), dtype: float64
# Median Grade per Marital status Marital status
# 1    12.285714
# 2    11.800000
# 3     6.125000
# 4    11.333333
# 5    11.333333
# 6     5.900000
# Name: Curricular units 2nd sem (grade), dtype: float64

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='Marital status',
            y ='Curricular units 1st sem (grade)',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = 'dark'
            )
plt.xlabel('Marital Status')
plt.ylabel('Grade')
plt.title('Average Grade per Marital Status (1st sem)')
plt.show()
plt.figure(figsize=(5,5))
sns.boxplot(x='Marital status',
            y ='Curricular units 2nd sem (grade)',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = 'dark'
            )
plt.xlabel('Marital Status')
plt.ylabel('Grade')
plt.title('Average Grade per Marital Status (2nd sem)')
plt.show()

# %% [markdown]
# #### Attendance

# %%
print('Mean Grade per Attendance', data.groupby('Daytime/evening attendance')['Curricular units 1st sem (grade)'].mean())
print('Median Grade per Attendance', data.groupby('Daytime/evening attendance')['Curricular units 1st sem (grade)'].median())
# Out:
# Mean Grade per Attendance Daytime/evening attendance
# 0     9.755793
# 1    10.749289
# Name: Curricular units 1st sem (grade), dtype: float64
# Median Grade per Attendance Daytime/evening attendance
# 0    11.500
# 1    12.375
# Name: Curricular units 1st sem (grade), dtype: float64

# %%
print('Mean Grade per Attendance', data.groupby('Daytime/evening attendance')['Curricular units 2nd sem (grade)'].mean())
print('Median Grade per Attendance', data.groupby('Daytime/evening attendance')['Curricular units 2nd sem (grade)'].median())
# Out:
# Mean Grade per Attendance Daytime/evening attendance
# 0     9.478723
# 1    10.322306
# Name: Curricular units 2nd sem (grade), dtype: float64
# Median Grade per Attendance Daytime/evening attendance
# 0    11.666667
# 1    12.300000
# Name: Curricular units 2nd sem (grade), dtype: float64

# %%
plt.figure(figsize=(4,4))
ans = {'0' : 'tomato','1': 'lightseagreen'}
sns.boxplot(x='Daytime/evening attendance',
            y ='Curricular units 1st sem (grade)',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = ans
            )
plt.xlabel('Attendance')
plt.ylabel('Grade')
plt.title('Average Grade per Attendance (1st sem)')
plt.show()

# %%
plt.figure(figsize=(4,4))
ans = {'0' : 'tomato','1': 'lightseagreen'}
sns.boxplot(x='Daytime/evening attendance',
            y ='Curricular units 2nd sem (grade)',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = ans
            )
plt.xlabel('Attendance')
plt.ylabel('Grade')
plt.title('Average Grade per Attendance (2nd sem)')
plt.show()

# %% [markdown]
# #### Scholarship Holder

# %%
print('Mean Grade per Scholarship Holder', data.groupby('Scholarship holder')['Curricular units 1st sem (grade)'].mean())
print('Median Grade per Scholarship Holder', data.groupby('Scholarship holder')['Curricular units 1st sem (grade)'].median())
print('Mean Grade per Scholarship Holder', data.groupby('Scholarship holder')['Curricular units 2nd sem (grade)'].mean())
print('Median Grade per Scholarship Holder', data.groupby('Scholarship holder')['Curricular units 2nd sem (grade)'].median())
# Out:
# Mean Grade per Scholarship Holder Scholarship holder
# 0    10.172145
# 1    12.058792
# Name: Curricular units 1st sem (grade), dtype: float64
# Median Grade per Scholarship Holder Scholarship holder
# 0    12.000000
# 1    12.833333
# Name: Curricular units 1st sem (grade), dtype: float64
# Mean Grade per Scholarship Holder Scholarship holder
# 0     9.687352
# 1    11.872596
# Name: Curricular units 2nd sem (grade), dtype: float64
# Median Grade per Scholarship Holder Scholarship holder
# 0    12.000000
# 1    12.791429
# Name: Curricular units 2nd sem (grade), dtype: float64

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='Scholarship holder',
            y ='Curricular units 1st sem (grade)',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = ans
            )
plt.xlabel('Scholarship Holder')
plt.ylabel('Grade')
plt.title('Average Grade per Scholarship Holder (1st sem)')
plt.show()

plt.figure(figsize=(5,5))
sns.boxplot(x='Scholarship holder',
            y ='Curricular units 2nd sem (grade)',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = ans
            )
plt.xlabel('Scholarship Holder')
plt.ylabel('Grade')
plt.title('Average Grade per Scholarship Holder (2nd sem)')
plt.show()

# %% [markdown]
# #### Age

# %%
print('Mean Grade per Age', data.groupby('age_bucket')['Curricular units 1st sem (grade)'].mean())
print('Median Grade per Age', data.groupby('age_bucket')['Curricular units 1st sem (grade)'].median())
print('Mean Grade per Age', data.groupby('age_bucket')['Curricular units 2nd sem (grade)'].mean())
print('Median Grade per Age', data.groupby('age_bucket')['Curricular units 2nd sem (grade)'].median())
# Out:
# Mean Grade per Age age_bucket
# <21      11.327853
# 21-30     9.988734
# 30-40     9.123457
# 40-50     9.504717
# 50+       9.325108
# Name: Curricular units 1st sem (grade), dtype: float64
# Median Grade per Age age_bucket
# <21      12.600000
# 21-30    12.000000
# 30-40    11.555556
# 40-50    11.800000
# 50+      12.166667
# Name: Curricular units 1st sem (grade), dtype: float64
# Mean Grade per Age age_bucket
# <21      11.033580
# 21-30     9.478408
# 30-40     8.384287
# 40-50     9.088619
# 50+       8.443806
# Name: Curricular units 2nd sem (grade), dtype: float64
# Median Grade per Age age_bucket
# <21      12.500000
# 21-30    11.909091
# 30-40    11.437500
# 40-50    11.725000
# 50+      11.714286
# Name: Curricular units 2nd sem (grade), dtype: float64

# %%
#Plot Age vs grades
plt.figure(figsize=(5,5))
sns.boxplot(x='age_bucket',
            y ='Curricular units 1st sem (grade)',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = 'deep'
            )
plt.xlabel('Age Bucket')
plt.ylabel('Grade')
plt.title('Average Grade per Age Bucket (1st sem)')
plt.show()

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='age_bucket',
            y ='Curricular units 2nd sem (grade)',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = 'deep'
            )
plt.xlabel('Age Bucket')
plt.ylabel('Grade')
plt.title('Average Grade per Age Bucket (2nd sem)')
plt.show()

# %%
# Check if there are correlation between age and grade
plt.figure(figsize=(4,4))
sns.scatterplot(x = 'Age at enrollment',
                y = 'Curricular units 1st sem (grade)',
                data = data,
                color = 'navy')
plt.xlabel('Age')
plt.ylabel('Grade')
plt.title('Age at Enrollment vs. Grade (1st sem)')
plt.show()

# %% [markdown]
# #### Course

# %%
print('Mean Grade per Course', data.groupby('Course')['Curricular units 1st sem (grade)'].mean())
print('Median Grade per Course', data.groupby('Course')['Curricular units 1st sem (grade)'].median())
print('Mean Grade per Course', data.groupby('Course')['Curricular units 2nd sem (grade)'].mean())
print('Median Grade per Course', data.groupby('Course')['Curricular units 2nd sem (grade)'].median())
# Out:
# Mean Grade per Course Course
# 1      9.639105
# 2      2.069818
# 3     10.569806
# 4     10.376684
# 5     12.081584
# 6     11.859385
# 7      8.565363
# 8     10.084748
# 9     10.120946
# 10    11.237505
# 11    10.460164
# 12    12.464836
# 13    10.334371
# 14    11.331277
# 15    11.694512
# 16    11.470468
# 17     9.102761
# Name: Curricular units 1st sem (grade), dtype: float64
# Median Grade per Course Course
# 1     12.181818
# 2      0.000000
# 3     12.000000
# 4     12.045455
# 5     12.666667
# 6     13.000000
# 7     11.600000
# 8     12.000000
# 9     11.333333
# 10    12.000000
# 11    11.666667
# 12    13.263333
# 13    12.164583
# 14    12.400000
# 15    12.666667
# 16    12.400000
# 17    11.000000
# Name: Curricular units 1st sem (grade), dtype: float64
# Mean Grade per Course Course
# 1      8.995238
# 2      2.082885
# 3      9.796105
# 4      9.476798
# 5     11.195936
# 6     11.160812
# 7      8.787700
# 8      9.684076
# 9      9.703696
# ...

# %%
sns.catplot(x = 'Course',
                y = 'Curricular units 1st sem (grade)',
                data = data,
            kind = 'violin',
            palette  = 'deep')
plt.xlabel('Course')
plt.ylabel('Grade')
plt.title('Grade Distribution per Course (1st sem)')

sns.catplot(x = 'Course',
                y = 'Curricular units 2nd sem (grade)',
                data = data,
            kind = 'violin',
            palette  = 'deep')
plt.xlabel('Course')
plt.ylabel('Grade')
plt.title('Grade Distribution per Course (2nd sem)')
plt.show()

# %% [markdown]
# #### International

# %%
print('Mean Grade per International', data.groupby('International')['Curricular units 1st sem (grade)'].mean())
print('Median Grade per International', data.groupby('International')['Curricular units 1st sem (grade)'].median())
print('Mean Grade per International', data.groupby('International')['Curricular units 2nd sem (grade)'].mean())
print('Median Grade per International', data.groupby('International')['Curricular units 2nd sem (grade)'].median())
# Out:
# Mean Grade per International International
# 0    10.635939
# 1    10.832320
# Name: Curricular units 1st sem (grade), dtype: float64
# Median Grade per International International
# 0    12.285714
# 1    12.333333
# Name: Curricular units 1st sem (grade), dtype: float64
# Mean Grade per International International
# 0    10.228991
# 1    10.277857
# Name: Curricular units 2nd sem (grade), dtype: float64
# Median Grade per International International
# 0    12.2
# 1    12.0
# Name: Curricular units 2nd sem (grade), dtype: float64

# %%
plt.figure(figsize=(5,5))
sns.boxplot(x='International',
            y ='Curricular units 1st sem (grade)',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = ans
            )
plt.xlabel('International')
plt.ylabel('Grade')
plt.title('Average Grade per Student (1st sem)')
plt.show()

plt.figure(figsize=(5,5))
sns.boxplot(x='International',
            y ='Curricular units 2nd sem (grade)',
            data= data,
              showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = ans
            )
plt.xlabel('International')
plt.ylabel('Grade')
plt.title('Average Grade per Student (2nd sem)')
plt.show()

# %% [markdown]
# ### Economic Indicators

# %% [markdown]
# #### Correlation matrix

# %%
#Plot the heat map of the economic indicators
columns_heatmap_ec = ['Inflation rate', 'GDP','Unemployment rate',]
corr_matrix_ec = data[columns_heatmap_ec].corr()
plt.figure(figsize=(5, 5))
sns.heatmap(corr_matrix_ec, cmap='summer', annot= True)
plt.title('Economical Indicators Correlation Matrix ')
plt.show()

# %%
#plot the pair plot
columnas_ec = ['Curricular units 1st sem (grade)','GDP','Inflation rate', 'Unemployment rate']
sns.pairplot(data[columnas_ec], height=2.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %% [markdown]
# ### Enrollment pattern

# %% [markdown]
# #### Age, Gender and Course

# %%
#Visualize using barplot
gen = {0: 'lightpink', 1: 'skyblue'}
plt.figure(figsize=(7,4))
sns.barplot(x='Course',
            y='Age at enrollment',
            hue='Gender',
            data=data,
            palette= gen)
plt.xlabel('Course')
plt.ylabel('Age')
plt.title('Age at Enrollment by Course and Gender')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# #### Age, Gender and Scholarship

# %%
gen = {0: 'lightpink', 1: 'skyblue'}
plt.figure(figsize=(5,4))
sns.barplot(x='Scholarship holder',
            y='Age at enrollment',
            hue='Gender',
            data=data,
            palette= gen)
plt.xlabel('Scholarship Holder')
plt.ylabel('Age')
plt.title('Age at Enrollment by Scholarship Holder and Gender')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# #### Age, Scholarship holder and International

# %%
#Visualize the correlation
resp = {0: 'tomato', 1: 'lightseagreen'}
plt.figure(figsize=(5,4))
sns.barplot(x='Scholarship holder',
            y='Age at enrollment',
            hue='International',
            data=data,
            palette= resp)
plt.xlabel('Scholarship Holder')
plt.ylabel('Age')
plt.title('Age at Enrollment by Scholarship Holder and International')
plt.legend(title='International')
plt.show()

# %% [markdown]
# ### Academic Performance

# %% [markdown]
# #### Marital status, Gender and Grade

# %%
#Visualize in boxplot
gen = {0: 'lightpink', 1: 'skyblue'}
plt.figure(figsize=(5,5))

sns.boxplot(x ='Marital status',
            y = 'Curricular units 1st sem (grade)',
            hue = 'Gender',
            data = data,
            showmeans= True,
             meanprops={'marker':'d',
                       'markerfacecolor':'white',
                        'markeredgecolor': 'gray',
                       'markersize':'6'},
            palette = gen)
plt.xlabel('Marital Status')
plt.ylabel('Grade')
plt.title('Grades (1st sem) by Marital Status and Gender')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# #### Course, Gender and Grade

# %%
#Visualize using barplot
gen = {0: 'lightpink', 1: 'skyblue'}
plt.figure(figsize=(8,5))
sns.barplot(x='Course',
            y='Curricular units 1st sem (grade)',
            hue='Gender',
            data=data,
            palette= gen)
plt.xlabel('Course')
plt.ylabel('Grade')
plt.title('Grades (1st sem) by Course and Gender')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# #### Age, Gender and Grade

# %%
sns.pairplot(data=data,
             vars=['Age at enrollment', 'Curricular units 1st sem (grade)'],
             hue='Gender')
plt.show()

# %%
sns.scatterplot(x='Age at enrollment',
                y='Curricular units 1st sem (grade)',
                hue='Gender',
                data=data,
                palette = gen)
plt.xlabel('Age at Enrollment')
plt.ylabel('Grade')
plt.title('Scatter Plot of Grades (1st sem) by Age at Enrollment and Gender')
plt.show()

# %% [markdown]
# #### Background and Grades

# %%
columns_heatmap_grade = ['Curricular units 1st sem (grade)',"Mother's qualification", "Father's qualification",
       "Mother's occupation", "Father's occupation", 'Curricular units 2nd sem (grade)']
corr_matrix_bg = data[columns_heatmap_grade].corr()
plt.figure(figsize=(5, 5))
sns.heatmap(corr_matrix_bg, cmap='pink', annot= True)
plt.title(' Background and Grade Correlation Matrix ')
plt.show()

# %% [markdown]
# ### Economic Indicators

# %% [markdown]
# #### Correlation Matrix

# %%
# Visualize the heat map between economic indicators and grades
economic_data = data[['Curricular units 1st sem (grade)',
                      'Curricular units 2nd sem (grade)',
                      'Unemployment rate',
                      'Inflation rate',
                      'GDP']]
correlation_matrix = economic_data.corr()
plt.figure(figsize=(6, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Matrix of Economic Indicators and Grades')
plt.show()

# %% [markdown]
# As the correlation matrix indicates a strong correlation between the variables 'Curricular units 1st sem (grade)' and 'Curricular units 2nd sem (grade)'.
# The Machine Learning algorithm of Linear Regression will be used between these two variables, to predict the student success.

# %% [markdown]
# # Random Forest Model

# %% [markdown]
# Random Forest Model is a Supervised Machine Learning Algorithm, in this case it is used to verify the strongest correlations between features such as gender, marital status, age, or scholarship holder that determine better student performance.

# %% [markdown]
# ### Build the model

# %%
# Import the useful libraries
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
# Define the variables
X_rd = data[['Gender', 'Age at enrollment','Marital status','Scholarship holder']]
y_rd = data['Curricular units 1st sem (grade)']

# %%
# Split the data into training and testing sets
X_train_rd, X_test_rd, y_train_rd, y_test_rd = train_test_split(X_rd, y_rd,
                                                                test_size=0.2,
                                                                random_state=100)

# %%
# Initialize the Random Forest model
RF = RandomForestRegressor(random_state=100)

# Fit the model to the training data
RF.fit(X_train_rd, y_train_rd)
# Out:
# RandomForestRegressor(random_state=100)

# %% [markdown]
# ###Evaluate the model

# %%
# Make predictions on the testing data
y_pred_rd = RF.predict(X_test_rd)

# %%
# Calculate the absolute errors
errors = abs(y_pred_rd - y_test_rd)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2))
# Out:
# Mean Absolute Error: 3.35

# %%
# Calculate the Mean Squared Error (MSE) to evaluate the model performance
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 21.273176648032955

# %%
# Feature importance
importance = RF.feature_importances_
feature_names = X.columns
print(feature_names)
print(importance)

plt.figure(figsize=(5,4))
sns.barplot(x=feature_names,
            y = importance,
            palette = 'pastel')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Feature Importance')
plt.xticks(rotation=90)
plt.show()
# Out:
# Index(['Gender', 'Age at enrollment', 'Marital status', 'Scholarship holder'], dtype='object')
# [0.16843301 0.57512351 0.1503194  0.10612408]

# %% [markdown]
# Between the features the most important one is 'Age at enrollment' so, a Linear Regression model will be applied in this feature as well.

# %% [markdown]
# # Linear Regression Model

# %% [markdown]
# Linear Regression Model is a Supervised Machine Learning Algorithm used to predict the response of a determined feature. In this case, Linear Regression models will be used to assess the academic performance based on Age and previous grades.

# %% [markdown]
# ## Grade (1st sem) vs Grade (2nd sem)

# %% [markdown]
# ### Build the model

# %%
#Import libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Defining the variables
X = data[['Curricular units 1st sem (grade)']]
y = data['Curricular units 2nd sem (grade)']

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.2,
                                                    random_state=100)
X_train.sample(5)
# Out:
#       Curricular units 1st sem (grade)
# 2007                         14.333333
# 3067                         12.320000
# 1999                         10.214286
# 2473                          0.000000
# 1282                          0.000000

# %%
#Verify the shape
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (3539, 1)
# (3539,)
# (885, 1)
# (885,)

# %%
# Define the model
LR = LinearRegression()
#Fit the model
LR.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
# Printing the intercept and coefficients of the linear model
print('Intercept:',LR.intercept_)
print('Coefficient:',LR.coef_)
# Out:
# Intercept: 0.6902413908951068
# Coefficient: [0.8967351]

# %% [markdown]
# The equation gets the form :\
#  Grades (2nd sem) = 0.69 + 0.896 * Grades 1st sem

# %% [markdown]
# ### Evaluate the model

# %%
# Make the predictions on the testing data
y_pred = LR.predict(X_test)

# %%
# Calculate R-squaredd to evaluate the fitting in the model
from sklearn.metrics import r2_score
r_squared = r2_score(y_test, y_pred)
print('R-squared:', r_squared)
# Out:
# R-squared: 0.6921921839127192

# %%
# Calculate the Mean Squared Error (MSE) to evaluate the model performance
mse = mean_squared_error(y_test, y_pred)
print('Mean Squared Error:', mse)
# Out:
# Mean Squared Error: 7.472196449659425

# %%
#Visualize the model
plt.figure(figsize=(6, 4))
plt.scatter(X_test,
            y_test,
            color='royalblue')
plt.plot(X_test,
         y_pred,
         color='red',
         linewidth=2,
         label = 'Linear Regression model ')
plt.xlabel('Grade (1st sem)')
plt.ylabel('Grade (2nd sem)')
plt.title('Linear Regression: Grade in 1st Sem vs. Grade in 2nd Sem')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# As noticed, the Linear Regression model does not have a good fit due to outliers, such as grades with a value of 0. However, the correlation is positive, indicating that if a student had good previous performance, their performance in the next semester will be similar.

# %% [markdown]
# ### Residual Analysis

# %%
#create the histofram for error terms
y_train_pred = LR.predict(X_train)
res = (y_train - y_train_pred)
plt.figure(figsize=(4,4))
sns.histplot(res,kde=True,
             color = 'skyblue')
plt.xlabel('Y_train - Y_predict')
plt.ylabel('Frequence')
plt.title('Error Terms Histogram')
plt.show()

# %%
# Create a scatterplot for x_train and computed residual
plt.figure(figsize=(4,4))
plt.scatter(X_train,
            res,
            color='skyblue',
            label='Training Data')
plt.xlabel('Grades (1st sem)')
plt.ylabel('Error Terms')
plt.title('Distribution of Residuals')
plt.show()

# %% [markdown]
# The residual analysis has a pattern that indicates the regression model does not have a good fitting as noticed before.

# %% [markdown]
# ## Grade (1st sem) vs Age

# %% [markdown]
# ### Build the model

# %%
# Defining the variables
X_age = data[['Age at enrollment']]
y_age = data['Curricular units 1st sem (grade)']

# %%
# Split the data into training and testing sets
X_train_age, X_test_age, y_train_age, y_test_age = train_test_split(X_age, y_age,
                                                    test_size=0.2,
                                                    random_state=100)
X_train_age.sample(5)
# Out:
#       Age at enrollment
# 1127                 19
# 3284                 25
# 2589                 18
# 3579                 20
# 306                  18

# %%
#Verify the shape
print(X_train_age.shape)
print(y_train_age.shape)
print(X_test_age.shape)
print(y_test_age.shape)
# Out:
# (3539, 1)
# (3539,)
# (885, 1)
# (885,)

# %%
# Define the model
LR_age= LinearRegression()
#Fit the model
LR_age.fit(X_train_age,y_train_age)
# Out:
# LinearRegression()

# %%
# Printing the intercept and coefficients of the linear model
print('Intercept:',LR_age.intercept_)
print('Coefficient:',LR_age.coef_)
# Out:
# Intercept: 12.911980827359109
# Coefficient: [-0.1027837]

# %% [markdown]
# The equation gets the form :\
#  Grades (1st sem) = 12.912 -0.102 * Age

# %% [markdown]
# ### Evaluate the model

# %%
# Make the predictions on the testing data
y_pred_age = LR_age.predict(X_test_age)

# %%
# Calculate R-squaredd to evaluate the fitting in the model
from sklearn.metrics import r2_score
r_squared_age = r2_score(y_test_age, y_pred_age)
print('R-squared:', r_squared_age)
# Out:
# R-squared: 0.0010534051117601084

# %%
mse_age = mean_squared_error(y_test_age, y_pred_age)
print('Mean Squared Error:', mse_age)
# Out:
# Mean Squared Error: 19.84640991708053

# %%
#Visualize the model
plt.figure(figsize=(6, 4))
plt.scatter(X_test_age,
            y_test_age,
            color='palegreen')
plt.plot(X_test_age,
         y_pred_age,
         color='red',
         linewidth=2,
         label = 'Linear Regression model ')
plt.xlabel('Age at Enrollment')
plt.ylabel('Grade (1st sem)')
plt.title('Linear Regression: Age at Enrollment vs Grades at 1st sem')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# As noticed, the Linear Regression model does not have a good fit due to outliers, such as grades with a value of 0 across all the ages. However, the correlation is negative, indicating that if a student is older the performance will be lower compared with the young ones.

# %% [markdown]
# ### Residual Analysis

# %%
#create the histofram for error terms
y_train_pred_age = LR_age.predict(X_train_age)
res_age = (y_train_age - y_train_pred_age)
plt.figure(figsize=(4,4))
sns.histplot(res_age,kde=True,
             color = 'palegreen')
plt.xlabel('Y_train - Y_predict')
plt.ylabel('Frequence')
plt.title('Error Terms Histogram')
plt.show()

# %%
# Create a scatterplot for x_train and computed residual
plt.figure(figsize=(4,4))
plt.scatter(X_train_age,
            res_age,
            color='palegreen',
            label='Training Data')
plt.xlabel('Age at Enrollment')
plt.ylabel('Error Terms')
plt.title('Distribution of Residuals')
plt.show()
